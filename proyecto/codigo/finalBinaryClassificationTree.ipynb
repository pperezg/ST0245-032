# %% [markdown]
# <a href="https://colab.research.google.com/github/pperezg/ST0245-032/blob/master/proyecto/codigo/finalBinaryClassificationTree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1648e0a2-abad-4500-a6f5-8fec9107d173" name="files[]" multiple disabled />
#      <output id="result-1648e0a2-abad-4500-a6f5-8fec9107d173">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving data_set_train.csv to data_set_train.csv

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ecdea721-a797-4ecb-b675-a628b46b6c77" name="files[]" multiple disabled />
#      <output id="result-ecdea721-a797-4ecb-b675-a628b46b6c77">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving data_set_test.csv to data_set_test.csv

# %%
import pandas as pd

trainingData = pd.read_csv('data_set_train.csv', delimiter = ',')
header = []

class Question:
    def __init__(self, column, value):
        self.column = column
        self.value = value

    def match(self, example):  #Can the chosen value 'pass the test'
        val = example[self.column]
        if is_numeric(val):
            return val >= self.value
        else:
            return val == self.value

    def __repr__(self): #Prints the question into words and numbers
        condition = "=="
        if is_numeric(self.value):
            condition = ">="
        return "Is %s %s %s?" % (
            header[self.column], condition, str(self.value))

class Leaf:
    def __init__(self, rows):
        totals = {}
        labels = set([row[-1] for row in rows])
        for label in labels:
            totals[label] = 0
        for row in rows:
            if row[-1]==label:
                totals[label]+=1
        self.predictions = totals

class Decision_Node:
    def __init__(self, question, true_branch, false_branch):
        self.question = question
        self.true_branch = true_branch
        self.false_branch = false_branch

def build_tree(rows): #Builds tree by creating questions and splits and evaluating them
    gain, question = find_best_split(rows)
    if gain==0:
        return Leaf(rows)
    
    true_rows, false_rows = partition(rows, question)
    true_branch = build_tree(true_rows)
    false_branch = build_tree(false_rows)

    return Decision_Node(question,true_branch,false_branch)

def classify(row, node): #Guides the path for data being evaluated
    if type(node)==Leaf:
        return node.predictions
    
    if node.question.match(row):
        return classify(row, node.true_branch)
    else:
        return classify(row, node.false_branch)

def unique_vals(rows, col):
    return set([row[col] for row in rows]) #Sets work just like lists but without element duplicates.

def print_tree(node, spacing=""): #Helps print final tree into a readable form
    if isinstance(node, Leaf):
        print(spacing + "Predict", node.predictions)
        return
    print(spacing + str(node.question))
    print(spacing + "--> True:")
    print_tree(node.true_branch, spacing + "  ")
    print(spacing + "--> False:")
    print_tree(node.false_branch, spacing + "  ")

def print_leaf(counts): #Prints final classifications and porcentages
    total = sum(counts.values()) * 1.0
    probs = {}
    for lbl in counts.keys():
        probs[lbl] = str(int(counts[lbl] / total * 100)) + '%'
    return probs


def is_numeric(value):
    if type(value)==int or type(value)==float:
        return True
    else:
        return False

def partition(rows, question): #Which values pass or don't a question
    truthOnes = []
    falseOnes = []
    for row in rows:
        if question.match(row):
            truthOnes.append(row)
        else:
            falseOnes.append(row)
    return truthOnes, falseOnes

def gini(rows):
  #Evaluation of impurity in data
  #Webography: 'http://www.learnbymarketing.com/481/decision-tree-flavors-gini-info-gain/'
    maximo = 1
    totals = {}
    labels = set([row[-1] for row in rows])
    for label in labels:
        totals[label] = 0
        for row in rows:
            if row[-1]==label:
                totals[label]+=1
    for label in totals:
        chances = totals[label]/len(rows)
        chsqrd = chances**2
        maximo = maximo - chsqrd
    return maximo
                

def info_gain(left, right, current_uncertainty):
  #How a partition helped the tree's knowledge
  #Webography: https://www.youtube.com/watch?v=c9Yg4Mrjztk&t=363s
    inTotal = len(left)+len(right)
    prcntg_left = len(left)/inTotal
    prcntg_right = len(right)/inTotal
    GainLeft = gini(left)
    GainRight = gini(right)
    return (current_uncertainty-(prcntg_left*GainLeft)-(prcntg_right-GainRight))

def find_best_split(rows):
    best_gain = 0
    best_question = None
    uncertainty = gini(rows)
    columns = len(rows[0])

    for column_ in range (0,columns):
        values = set(row[column_] for row in rows)
        for val in values:
            question = Question(column_, val)
            true_rows, false_rows = partition(rows, question)
            if len(true_rows)==0 or len(false_rows)==0:
                continue
            gain = info_gain(true_rows, false_rows, uncertainty)
            if gain>=best_gain:
                best_gain, best_question = gain, question

    return best_gain, best_question

if __name__ == '__main__':
    header = trainingData.columns.values.tolist()
    listOfTrainingData = trainingData.values.tolist()
    tree = build_tree(listOfTrainingData)
    print_tree(tree)

    testingData = pd.read_csv('data_set_test.csv', delimiter = ',')
    listOfTestingData = testingData.values.tolist()
    real_results = []
    for row in listOfTestingData:
      real_results.append(row[-1])
    classified = []
    for row in listOfTestingData:
        for n in print_leaf(classify(row, tree)):
          if "100" in print_leaf(classify(row, tree))[n]:
            classified.append(n)
    counted = len(real_results)
    goodOnes = 0
    for n in range (0,counted):
      if real_results[n]==classified[n]:
        goodOnes += 1
    print('')
    print('{}% de aciertos.'.format(goodOnes/counted))
    
    
#Other Webography: https://www.youtube.com/watch?v=LDRbO9a6XPU&t=336s
# https://github.com/random-forests/tutorials/blob/master/decision_tree.ipynb
# https://github.com/mauriciotoro/ST0245-Eafit/tree/master/proyecto/CodigoYaEmpezado
# https://github.com/michaeldorner/DecisionTrees
# https://github.com/gaganmalhotra/Decision-Tree-Implementation-in-Python/blob/master/Tree_Model.py
# Out:
# Is soil_temperature >= 19.25?
# --> True:
#   Is soil_temperature >= 19.5?
#   --> True:
#     Is illuminance >= 971?
#     --> True:
#       Is illuminance >= 981?
#       --> True:
#         Is ph >= 6.04?
#         --> True:
#           Is ph >= 6.08?
#           --> True:
#             Is illuminance >= 1103?
#             --> True:
#               Is illuminance >= 1116?
#               --> True:
#                 Is illuminance >= 1125?
#                 --> True:
#                   Is illuminance >= 1162?
#                   --> True:
#                     Is illuminance >= 1192?
#                     --> True:
#                       Is illuminance >= 1237?
#                       --> True:
#                         Is soil_moisture >= 28.26?
#                         --> True:
#                           Is illuminance >= 1341?
#                           --> True:
#                             Is illuminance >= 1444?
#                             --> True:
#                               Is illuminance >= 1656?
#                               --> True:
#                                 Is illuminance >= 1750?
#                                 --> True:
#                                   Is illuminance >= 1790?
#                                   --> True:
#                                     Is illuminance >= 1807?
#                                     --> True:
#                                       Is illuminance >= 1884?
#                                       --> True:
#                                         Is illuminance >= 1910?
#                                         --> True:
#                                           Is illuminance >= 1926?
#                                           --> True:
#                                             Is illuminance >= 1981?
#                                             --> True:
#                                               Is ph >= 6.15?
#                                               --> True:
#                                                 Is ph >= 6.19?
#                                                 --> True:
#                                                   Is illuminance >= 2137?
#                                                   --> True:
#                                                     Is illuminance >= 2149?
#                                                     --> True:
#                                                       Is illuminance >= 2186?
#                                                       --> True:
#                                                         Is illuminance >= 2317?
#                                                         --> True:
#                                                           Is illuminance >= 2323?
#                                                           --> True:
#                                                             Is illuminance >= 2349?
#                                                             --> True:
#                                                               Is illuminance >= 2369?
#                                                               --> True:
#                                                                 Is illuminance >= 2379?
#                                                                 --> True:
#                                                                   Is illuminance >= 2515?
#                                                                   --> True:
#                                                                     Is illuminance >= 2523?
#                                                                     --> True:
#                                                                       Is illuminance >= 2531?
#                                                                       --> True:
#                                                                         Is illuminance >= 2587?
#                                                                         --> True:
#                                                                           Is soil_moisture >= 28.62?
#                                                                           --> True:
#                                                                             Is illuminance >= 2642?
#                                                                             --> True:
#                                                                               Is soil_moisture >= 32.61?
#                                                                               --> True:
#                                                                                 Is env_humidity >= 36?
#                                                                                 --> True:
#                                                                                   Is illuminance >= 2793?
#                                                                                   --> True:
#                                                                                     Is illuminance >= 2874?
#                                                                                     --> True:
#                                                                                       Is illuminance >= 2914?
#                                                                                       --> True:
#                                                                                         Is illuminance >= 2970?
#                                                                                         --> True:
#                                                                                           Is illuminance >= 2978?
#                                                                                           --> True:
#                                                                                             Is env_humidity >= 38?
#                                                                                             --> True:
#                                                                                               Is env_humidity >= 45?
#                                                                                               --> True:
#                                                                                                 Is env_humidity >= 47?
#                                                                                                 --> True:
#                                                                                                   Is env_temperature >= 21?
#                                                                                                   --> True:
#                                                                                                     Is env_temperature >= 23?
#                                                                                                     --> True:
#                                                                                                       Is illuminance >= 3524?
#                                                                                                       --> True:
#                                                                                                         Is env_humidity >= 55?
#                                                                                                         --> True:
#                                                                                                           Is env_humidity >= 56?
#                                                                                                           --> True:
#                                                                                                             Is env_humidity >= 58?
#                                                                                                             --> True:
#                                                                                                               Is env_humidity >= 60?
#                                                                                                               --> True:
#                                                                                                                 Is soil_temperature >= 20.0?
#                                                                                                                 --> True:
#                                                                                                                   Is env_temperature >= 25?
#                                                                                                                   --> True:
#                                                                                                                     Is ph >= 6.36?
#                                                                                                                     --> True:
#                                                                                                                       Is ph >= 6.45?
#                                                                                                                       --> True:
#                                                                                                                         Is ph >= 6.48?
#                                                                                                                         --> True:
#                                                                                                                           Is ph >= 6.56?
#                                                                                                                           --> True:
#                                                                                                                             Is ph >= 6.63?
#                                                                                                                             --> True:
#                                                                                                                               Is ph >= 6.69?
#                                                                                                                               --> True:
#                                                                                                                                 Is soil_moisture >= 56.8?
#                                                                                                                                 --> True:
#                                                                                                                                   Predict {'no': 12}
#                                                                                                                                 --> False:
#                                                                                                                                   Is env_humidity >= 79?
#                                                                                                                                   --> True:
#                                                                                                                                     Is soil_moisture >= 47.46?
#                                                                                                                                     --> True:
#                                                                                                                                       Predict {'yes': 3}
#                                                                                                                                     --> False:
#                                                                                                                                       Is label == no?
#                                                                                                                                       --> True:
#                                                                                                                                         Predict {'no': 3}
#                                                                                                                                       --> False:
#                                                                                                                                         Predict {'yes': 1}
#                                                                                                                                   --> False:
#                                                                                                                                     Predict {'yes': 0, 'no': 1}
#                                                                                                                               --> False:
#                                                                                                                                 Predict {'yes': 0, 'no': 1}
#                                                                                                                             --> False:
#                                                                                                                               Is illuminance >= 7679?
#                                                                                                                               --> True:
#                                                                                                                                 Predict {'yes': 0, 'no': 1}
#                                                                                                                               --> False:
#                                                                                                                                 Predict {'yes': 0, 'no': 1}
#                                                                                                                           --> False:
#                                                                                                                             Predict {'yes': 0, 'no': 1}
#                                                                                                                         --> False:
#                                                                                                                           Predict {'yes': 0, 'no': 1}
#                                                                                                                       --> False:
#                                                                                                                         Is env_humidity >= 98?
#                                                                                                                         --> True:
#                                                                                                                           Predict {'yes': 2}
#                                                                                                                         --> False:
#                                                                                                                           Is env_temperature >= 32?
#                                                                                                                           --> True:
#                                                                                                                             Predict {'no': 1}
#                                                                                                                           --> False:
#                                                                                                                             Predict {'yes': 0, 'no': 1}
#                                                                                                                     --> False:
#                                                                                                                       Is env_humidity >= 99?
#                                                                                                                       --> True:
#                                                                                                                         Predict {'yes': 2}
#                                                                                                                       --> False:
#                                                                                                                         Is soil_moisture >= 75.2?
#                                                                                                                         --> True:
#                                                                                                                           Predict {'no': 1}
#                                                                                                                         --> False:
#                                                                                                                           Predict {'yes': 0, 'no': 1}
#                                                                                                                   --> False:
#                                                                                                                     Is soil_temperature >= 20.5?
#                                                                                                                     --> True:
#                                                                                                                       Is soil_temperature >= 20.75?
#                                                                                                                       --> True:
#                                                                                                                         Is illuminance >= 4089?
#                                                                                                                         --> True:
#                                                                                                                           Is soil_moisture >= 53.99?
#                                                                                                                           --> True:
#                                                                                                                             Predict {'yes': 4}
#                                                                                                                           --> False:
#                                                                                                                             Is illuminance >= 8237?
#                                                                                                                             --> True:
#                                                                                                                               Predict {'no': 1}
#                                                                                                                             --> False:
#                                                                                                                               Predict {'yes': 0, 'no': 1}
#                                                                                                                         --> False:
#                                                                                                                           Predict {'yes': 0, 'no': 1}
#                                                                                                                       --> False:
#                                                                                                                         Predict {'yes': 0, 'no': 1}
#                                                                                                                     --> False:
#                                                                                                                       Predict {'yes': 0, 'no': 1}
#                                                                                                                 --> False:
#                                                                                                                   Is env_temperature >= 30?
#                                                                                                                   --> True:
#                                                                                                                     Predict {'no': 1}
#                                                                                                                   --> False:
#                                                                                                                     Predict {'yes': 0, 'no': 1}
#                                                                                                               --> False:
#                                                                                                                 Is illuminance >= 10687?
#                                                                                                                 --> True:
#                                                                                                                   Predict {'no': 1}
#                                                                                                                 --> False:
#                                                                                                                   Predict {'yes': 0, 'no': 1}
#                                                                                                             --> False:
#                                                                                                               Is env_temperature >= 33?
#                                                                                                               --> True:
#                                                                                                                 Predict {'no': 1}
#                                                                                                               --> False:
#                                                                                                                 Predict {'yes': 0, 'no': 1}
#                                                                                                           --> False:
#                                                                                                             Is env_temperature >= 32?
#                                                                                                             --> True:
#                                                                                                               Predict {'no': 1}
#                                                                                                             --> False:
#                                                                                                               Predict {'yes': 0, 'no': 1}
#                                                                                                         --> False:
#                                                                                                           Is illuminance >= 5029?
#                                                                                                           --> True:
#                                                                                                             Is env_temperature >= 34?
#                                                                                                             --> True:
#                                                                                                               Is env_temperature >= 35?
#                                                                                                               --> True:
#                                                                                                                 Is env_temperature >= 36?
#                                                                                                                 --> True:
#                                                                                                                   Predict {'yes': 2}
#                                                                                                                 --> False:
#                                                                                                                   Predict {'yes': 0, 'no': 1}
#                                                                                                               --> False:
#                                                                                                                 Predict {'yes': 0, 'no': 1}
#                                                                                                             --> False:
#                                                                                                               Predict {'yes': 0, 'no': 1}
#                                                                                                           --> False:
#                                                                                                             Predict {'yes': 0, 'no': 1}
#                                                                                                       --> False:
#                                                                                                         Is env_humidity >= 66?
#                                                                                                         --> True:
#                                                                                                           Is env_humidity >= 77?
#                                                                                                           --> True:
#                                                                                                             Is env_temperature >= 27?
#                                                                                                             --> True:
#                                                                                                               Predict {'no': 3}
#                                                                                                             --> False:
#                                                                                                               Is env_humidity >= 96?
#                                                                                                               --> True:
#                                                                                                                 Predict {'yes': 1}
#                                                                                                               --> False:
#                                                                                                                 Predict {'yes': 0, 'no': 1}
#                                                                                                           --> False:
#                                                                                                             Predict {'yes': 0, 'no': 1}
#                                                                                                         --> False:
#                                                                                                           Predict {'yes': 0, 'no': 1}
#                                                                                                     --> False:
#                                                                                                       Is soil_moisture >= 71.6?
#                                                                                                       --> True:
#                                                                                                         Predict {'no': 2}
#                                                                                                       --> False:
#                                                                                                         Is illuminance >= 7141?
#                                                                                                         --> True:
#                                                                                                           Predict {'yes': 1}
#                                                                                                         --> False:
#                                                                                                           Predict {'yes': 0, 'no': 1}
#                                                                                                   --> False:
#                                                                                                     Is soil_moisture >= 59.23?
#                                                                                                     --> True:
#                                                                                                       Predict {'no': 1}
#                                                                                                     --> False:
#                                                                                                       Predict {'yes': 0, 'no': 1}
#                                                                                                 --> False:
#                                                                                                   Predict {'yes': 0, 'no': 1}
#                                                                                               --> False:
#                                                                                                 Is env_temperature >= 34?
#                                                                                                 --> True:
#                                                                                                   Is env_humidity >= 40?
#                                                                                                   --> True:
#                                                                                                     Is env_temperature >= 36?
#                                                                                                     --> True:
#                                                                                                       Is illuminance >= 6831?
#                                                                                                       --> True:
#                                                                                                         Predict {'yes': 2}
#                                                                                                       --> False:
#                                                                                                         Is env_temperature >= 37?
#                                                                                                         --> True:
#                                                                                                           Predict {'no': 1}
#                                                                                                         --> False:
#                                                                                                           Predict {'yes': 0, 'no': 1}
#                                                                                                     --> False:
#                                                                                                       Predict {'yes': 0, 'no': 1}
#                                                                                                   --> False:
#                                                                                                     Is illuminance >= 7415?
#                                                                                                     --> True:
#                                                                                                       Predict {'no': 1}
#                                                                                                     --> False:
#                                                                                                       Predict {'yes': 0, 'no': 1}
#                                                                                                 --> False:
#                                                                                                   Predict {'yes': 0, 'no': 1}
#                                                                                             --> False:
#                                                                                               Is illuminance >= 6043?
#                                                                                               --> True:
#                                                                                                 Predict {'no': 2}
#                                                                                               --> False:
#                                                                                                 Is illuminance >= 5906?
#                                                                                                 --> True:
#                                                                                                   Predict {'yes': 1}
#                                                                                                 --> False:
#                                                                                                   Predict {'yes': 0, 'no': 1}
#                                                                                           --> False:
#                                                                                             Predict {'yes': 0, 'no': 1}
#                                                                                         --> False:
#                                                                                           Is env_humidity >= 99?
#                                                                                           --> True:
#                                                                                             Predict {'yes': 0, 'no': 1}
#                                                                                           --> False:
#                                                                                             Predict {'yes': 0, 'no': 1}
#                                                                                       --> False:
#                                                                                         Is env_temperature >= 23?
#                                                                                         --> True:
#                                                                                           Is soil_temperature >= 26.0?
#                                                                                           --> True:
#                                                                                             Predict {'yes': 0, 'no': 1}
#                                                                                           --> False:
#                                                                                             Predict {'yes': 0, 'no': 1}
#                                                                                         --> False:
#                                                                                           Predict {'yes': 0, 'no': 1}
#                                                                                     --> False:
#                                                                                       Is env_humidity >= 99?
#                                                                                       --> True:
#                                                                                         Predict {'yes': 0, 'no': 1}
#                                                                                       --> False:
#                                                                                         Predict {'yes': 0, 'no': 1}
#                                                                                   --> False:
#                                                                                     Is env_temperature >= 24?
#                                                                                     --> True:
#                                                                                       Is soil_moisture >= 58.7?
#                                                                                       --> True:
#                                                                                         Predict {'yes': 2}
#                                                                                       --> False:
#                                                                                         Is env_humidity >= 99?
#                                                                                         --> True:
#                                                                                           Predict {'no': 1}
#                                                                                         --> False:
#                                                                                           Predict {'yes': 0, 'no': 1}
#                                                                                     --> False:
#                                                                                       Predict {'yes': 0, 'no': 1}
#                                                                                 --> False:
#                                                                                   Is illuminance >= 7452?
#                                                                                   --> True:
#                                                                                     Predict {'yes': 0, 'no': 1}
#                                                                                   --> False:
#                                                                                     Predict {'yes': 0, 'no': 1}
#                                                                               --> False:
#                                                                                 Is env_humidity >= 47?
#                                                                                 --> True:
#                                                                                   Is env_humidity >= 91?
#                                                                                   --> True:
#                                                                                     Is env_humidity >= 97?
#                                                                                     --> True:
#                                                                                       Predict {'yes': 0, 'no': 1}
#                                                                                     --> False:
#                                                                                       Predict {'yes': 0, 'no': 1}
#                                                                                   --> False:
#                                                                                     Predict {'yes': 0, 'no': 1}
#                                                                                 --> False:
#                                                                                   Predict {'yes': 0, 'no': 1}
#                                                                             --> False:
#                                                                               Predict {'yes': 0, 'no': 1}
#                                                                           --> False:
#                                                                             Is illuminance >= 3868?
#                                                                             --> True:
#                                                                               Predict {'yes': 2}
#                                                                             --> False:
#                                                                               Is env_humidity >= 97?
#                                                                               --> True:
#                                                                                 Predict {'no': 1}
#                                                                               --> False:
#                                                                                 Predict {'yes': 0, 'no': 1}
#                                                                         --> False:
#                                                                           Is env_humidity >= 92?
#                                                                           --> True:
#                                                                             Is env_temperature >= 26?
#                                                                             --> True:
#                                                                               Predict {'yes': 1}
#                                                                             --> False:
#                                                                               Predict {'yes': 0, 'no': 1}
#                                                                           --> False:
#                                                                             Predict {'yes': 0, 'no': 1}
#                                                                       --> False:
#                                                                         Predict {'yes': 0, 'no': 1}
#                                                                     --> False:
#                                                                       Predict {'yes': 0, 'no': 1}
#                                                                   --> False:
#                                                                     Is env_humidity >= 80?
#                                                                     --> True:
#                                                                       Is soil_moisture >= 37.68?
#                                                                       --> True:
#                                                                         Is soil_temperature >= 22.0?
#                                                                         --> True:
#                                                                           Predict {'yes': 0, 'no': 1}
#                                                                         --> False:
#                                                                           Predict {'yes': 0, 'no': 1}
#                                                                       --> False:
#                                                                         Predict {'yes': 0, 'no': 1}
#                                                                     --> False:
#                                                                       Predict {'yes': 0, 'no': 1}
#                                                                 --> False:
#                                                                   Predict {'yes': 0, 'no': 1}
#                                                               --> False:
#                                                                 Predict {'yes': 0, 'no': 1}
#                                                             --> False:
#                                                               Predict {'yes': 0, 'no': 1}
#                                                           --> False:
#                                                             Predict {'yes': 0, 'no': 1}
#                                                         --> False:
#                                                           Is env_temperature >= 21?
#                                                           --> True:
#                                                             Is soil_moisture >= 42.75?
#                                                             --> True:
#                                                               Is soil_moisture >= 51.81?
#                                                               --> True:
#                                                                 Is soil_moisture >= 56.52?
#                                                                 --> True:
#                                                                   Is ph >= 6.38?
#                                                                   --> True:
#                                                                     Is ph >= 7.18?
#                                                                     --> True:
#                                                                       Predict {'yes': 0, 'no': 1}
#                                                                     --> False:
#                                                                       Predict {'yes': 0, 'no': 1}
#                                                                   --> False:
#                                                                     Predict {'yes': 0, 'no': 1}
#                                                                 --> False:
#                                                                   Predict {'yes': 0, 'no': 1}
#                                                               --> False:
#                                                                 Predict {'yes': 0, 'no': 1}
#                                                             --> False:
#                                                               Predict {'yes': 0, 'no': 1}
#                                                           --> False:
#                                                             Predict {'yes': 0, 'no': 1}
#                                                       --> False:
#                                                         Predict {'yes': 0, 'no': 1}
#                                                     --> False:
#                                                       Predict {'yes': 0, 'no': 1}
#                                                   --> False:
#                                                     Is soil_moisture >= 34.06?
#                                                     --> True:
#                                                       Is soil_moisture >= 52.17?
#                                                       --> True:
#                                                         Is env_humidity >= 99?
#                                                         --> True:
#                                                           Is soil_moisture >= 59.2?
#                                                           --> True:
#                                                             Is env_temperature >= 20?
#                                                             --> True:
#                                                               Predict {'no': 1}
#                                                             --> False:
#                                                               Predict {'yes': 0, 'no': 1}
#                                                           --> False:
#                                                             Predict {'yes': 0, 'no': 1}
#                                                         --> False:
#                                                           Predict {'yes': 0, 'no': 1}
#                                                       --> False:
#                                                         Predict {'yes': 0, 'no': 1}
#                                                     --> False:
#                                                       Predict {'yes': 0, 'no': 1}
#                                                 --> False:
#                                                   Is env_temperature >= 23?
#                                                   --> True:
#                                                     Is illuminance >= 3625?
#                                                     --> True:
#                                                       Predict {'yes': 0, 'no': 1}
#                                                     --> False:
#                                                       Predict {'yes': 0, 'no': 1}
#                                                   --> False:
#                                                     Predict {'yes': 0, 'no': 1}
#                                               --> False:
#                                                 Is env_temperature >= 24?
#                                                 --> True:
#                                                   Is env_humidity >= 95?
#                                                   --> True:
#                                                     Predict {'yes': 4}
#                                                   --> False:
#                                                     Is soil_moisture >= 73.55?
#                                                     --> True:
#                                                       Predict {'no': 2}
#                                                     --> False:
#                                                       Predict {'yes': 0, 'no': 1}
#                                                 --> False:
#                                                   Predict {'yes': 0, 'no': 1}
#                                             --> False:
#                                               Is env_humidity >= 99?
#                                               --> True:
#                                                 Is env_temperature >= 25?
#                                                 --> True:
#                                                   Predict {'no': 1}
#                                                 --> False:
#                                                   Is soil_moisture >= 51.45?
#                                                   --> True:
#                                                     Predict {'yes': 0, 'no': 1}
#                                                   --> False:
#                                                     Predict {'yes': 0, 'no': 1}
#                                               --> False:
#                                                 Predict {'yes': 0, 'no': 1}
#                                           --> False:
#                                             Predict {'yes': 0, 'no': 1}
#                                         --> False:
#                                           Predict {'yes': 0, 'no': 1}
#                                       --> False:
#                                         Is ph >= 6.31?
#                                         --> True:
#                                           Is ph >= 6.67?
#                                           --> True:
#                                             Is soil_moisture >= 62.0?
#                                             --> True:
#                                               Predict {'no': 2}
#                                             --> False:
#                                               Is env_temperature >= 27?
#                                               --> True:
#                                                 Predict {'yes': 1}
#                                               --> False:
#                                                 Predict {'yes': 0, 'no': 1}
#                                           --> False:
#                                             Predict {'yes': 0, 'no': 1}
#                                         --> False:
#                                           Predict {'yes': 0, 'no': 1}
#                                     --> False:
#                                       Predict {'yes': 0, 'no': 1}
#                                   --> False:
#                                     Is env_temperature >= 21?
#                                     --> True:
#                                       Predict {'yes': 0, 'no': 1}
#                                     --> False:
#                                       Predict {'yes': 0, 'no': 1}
#                                 --> False:
#                                   Is env_temperature >= 26?
#                                   --> True:
#                                     Is soil_moisture >= 30.07?
#                                     --> True:
#                                       Predict {'yes': 0, 'no': 1}
#                                     --> False:
#                                       Predict {'yes': 0, 'no': 1}
#                                   --> False:
#                                     Predict {'yes': 0, 'no': 1}
#                               --> False:
#                                 Is soil_moisture >= 31.16?
#                                 --> True:
#                                   Is soil_temperature >= 20.0?
#                                   --> True:
#                                     Is ph >= 6.56?
#                                     --> True:
#                                       Is env_temperature >= 22?
#                                       --> True:
#                                         Is env_temperature >= 27?
#                                         --> True:
#                                           Predict {'yes': 2}
#                                         --> False:
#                                           Predict {'yes': 0, 'no': 1}
#                                       --> False:
#                                         Predict {'yes': 0, 'no': 1}
#                                     --> False:
#                                       Predict {'yes': 0, 'no': 1}
#                                   --> False:
#                                     Predict {'yes': 0, 'no': 1}
#                                 --> False:
#                                   Predict {'yes': 0, 'no': 1}
#                             --> False:
#                               Is soil_moisture >= 47.46?
#                               --> True:
#                                 Is soil_temperature >= 20.0?
#                                 --> True:
#                                   Is label == yes?
#                                   --> True:
#                                     Predict {'yes': 2}
#                                   --> False:
#                                     Predict {'no': 1}
#                                 --> False:
#                                   Is env_temperature >= 20?
#                                   --> True:
#                                     Predict {'yes': 1}
#                                   --> False:
#                                     Predict {'yes': 0, 'no': 1}
#                               --> False:
#                                 Is soil_temperature >= 23.75?
#                                 --> True:
#                                   Predict {'yes': 0, 'no': 1}
#                                 --> False:
#                                   Predict {'yes': 0, 'no': 1}
#                           --> False:
#                             Is env_humidity >= 92?
#                             --> True:
#                               Is soil_temperature >= 20.75?
#                               --> True:
#                                 Predict {'yes': 3}
#                               --> False:
#                                 Is illuminance >= 1328?
#                                 --> True:
#                                   Predict {'no': 1}
#                                 --> False:
#                                   Predict {'yes': 0, 'no': 1}
#                             --> False:
#                               Predict {'yes': 0, 'no': 1}
#                         --> False:
#                           Is env_humidity >= 38?
#                           --> True:
#                             Is illuminance >= 1581?
#                             --> True:
#                               Is illuminance >= 1603?
#                               --> True:
#                                 Is soil_temperature >= 21.25?
#                                 --> True:
#                                   Is env_humidity >= 81?
#                                   --> True:
#                                     Predict {'no': 5}
#                                   --> False:
#                                     Is ph >= 7.05?
#                                     --> True:
#                                       Is env_temperature >= 32?
#                                       --> True:
#                                         Predict {'yes': 2}
#                                       --> False:
#                                         Predict {'yes': 0, 'no': 1}
#                                     --> False:
#                                       Predict {'yes': 0, 'no': 1}
#                                 --> False:
#                                   Is env_temperature >= 25?
#                                   --> True:
#                                     Predict {'yes': 0, 'no': 1}
#                                   --> False:
#                                     Predict {'yes': 0, 'no': 1}
#                               --> False:
#                                 Predict {'yes': 0, 'no': 1}
#                             --> False:
#                               Is env_temperature >= 28?
#                               --> True:
#                                 Predict {'yes': 1}
#                               --> False:
#                                 Predict {'yes': 0, 'no': 1}
#                           --> False:
#                             Predict {'yes': 0, 'no': 1}
#                       --> False:
#                         Predict {'yes': 0, 'no': 1}
#                     --> False:
#                       Is env_temperature >= 21?
#                       --> True:
#                         Predict {'yes': 0, 'no': 1}
#                       --> False:
#                         Predict {'yes': 0, 'no': 1}
#                   --> False:
#                     Predict {'yes': 0, 'no': 1}
#                 --> False:
#                   Predict {'yes': 0, 'no': 1}
#               --> False:
#                 Predict {'yes': 0, 'no': 1}
#             --> False:
#               Is env_humidity >= 98?
#               --> True:
#                 Is soil_moisture >= 33.7?
#                 --> True:
#                   Is soil_moisture >= 56.4?
#                   --> True:
#                     Is soil_temperature >= 22.0?
#                     --> True:
#                       Predict {'no': 2}
#                     --> False:
#                       Is illuminance >= 1086?
#                       --> True:
#                         Predict {'yes': 1}
#                       --> False:
#                         Predict {'yes': 0, 'no': 1}
#                   --> False:
#                     Predict {'yes': 0, 'no': 1}
#                 --> False:
#                   Predict {'yes': 0, 'no': 1}
#               --> False:
#                 Predict {'yes': 0, 'no': 1}
#           --> False:
#             Predict {'yes': 0, 'no': 1}
#         --> False:
#           Is env_humidity >= 75?
#           --> True:
#             Is env_temperature >= 20?
#             --> True:
#               Is env_temperature >= 23?
#               --> True:
#                 Predict {'no': 2}
#               --> False:
#                 Is illuminance >= 7481?
#                 --> True:
#                   Predict {'yes': 1}
#                 --> False:
#                   Predict {'yes': 0, 'no': 1}
#             --> False:
#               Is illuminance >= 4733?
#               --> True:
#                 Predict {'yes': 1}
#               --> False:
#                 Predict {'yes': 0, 'no': 1}
#           --> False:
#             Is illuminance >= 3786?
#             --> True:
#               Predict {'yes': 0, 'no': 1}
#             --> False:
#               Predict {'yes': 0, 'no': 1}
#       --> False:
#         Predict {'yes': 0, 'no': 1}
#     --> False:
#       Is soil_moisture >= 32.25?
#       --> True:
#         Is env_temperature >= 21?
#         --> True:
#           Is env_temperature >= 28?
#           --> True:
#             Predict {'no': 2}
#           --> False:
#             Is illuminance >= 949?
#             --> True:
#               Predict {'yes': 1}
#             --> False:
#               Predict {'yes': 0, 'no': 1}
#         --> False:
#           Is illuminance >= 951?
#           --> True:
#             Predict {'yes': 2}
#           --> False:
#             Is illuminance >= 948?
#             --> True:
#               Predict {'no': 1}
#             --> False:
#               Predict {'yes': 0, 'no': 1}
#       --> False:
#         Predict {'yes': 0, 'no': 1}
#   --> False:
#     Is env_temperature >= 19?
#     --> True:
#       Is illuminance >= 1852?
#       --> True:
#         Is illuminance >= 2185?
#         --> True:
#           Predict {'yes': 0, 'no': 1}
#         --> False:
#           Predict {'yes': 0, 'no': 1}
#       --> False:
#         Predict {'yes': 0, 'no': 1}
#     --> False:
#       Predict {'yes': 0, 'no': 1}
# --> False:
#   Is illuminance >= 2106?
#   --> True:
#     Predict {'yes': 0, 'no': 1}
#   --> False:
#     Predict {'yes': 0, 'no': 1}
#
# 0.7966666666666666% de aciertos.
